# %%
import pandas as pd

# %%
df = pd.read_csv("House Price India.csv")

# %%
# STEP 1:Read the required data from the csv using pandas to inspect structure and columns

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
# STEP2: To show that data is imported correctly in the notebook with all the column aligned properly.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
# STEP 3: To check the data types of coloumns and non null values before analysis to reduce error.

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
# STEP 4: Total number of null values present in the columns of the data and check the coloumn is safe for calculation or not.

# %%
df_drop = df.dropna()

# %%
# STEP 5: To check the missing values for analysis and handel them according to their data types (exceptionally this data set has no null values).

# %%
df["Price"] = df["Price"].fillna(df["Price"].mean())

# %%
# STEP 6: To fill the missing price value with the mean value for the proper visuallisation of the data reduce error during graph formation.

# %%
df["living area"] = df["living area"].fillna(df["living area"].median())

# %%
# STEP 7 : Filling the categorical data with the median value.

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
# STEP 8: Again check the null values after modification

# %%
df.shape[0]
# Out:
# 14620

# %%
df["id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
# STEP 9: No duplicates were found in the id column of the data, as id should be uniques for every order.

# %%
df.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# ...

# %%
# STEP 10: To check the data types of the columns for Correct calculations, avoid erorrs and data validation , e.g, if a date column has an types int we can not 
#         analyse sales over month and year

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
# STEP 11: To convert the dates to the datetime format for the analysis and trends over months.

# %%
df["number of bathrooms"] = df["number of bathrooms"].astype(int)  #changing datatypes

# %%
df["Postal Code"] = df["Postal Code"].astype("category")  #changing data types

# %%
df["waterfront present"] = df["waterfront present"].astype(bool)  #changing datatypes

# %%
df.dtypes
# Out:
# id                                                int64
# Date                                     datetime64[ns]
# number of bedrooms                                int64
# number of bathrooms                               int64
# living area                                       int64
# lot area                                          int64
# number of floors                                float64
# waterfront present                                 bool
# number of views                                   int64
# condition of the house                            int64
# grade of the house                                int64
# Area of the house(excluding basement)             int64
# Area of the basement                              int64
# Built Year                                        int64
# Renovation Year                                   int64
# Postal Code                                    category
# Lattitude                                       float64
# ...

# %%
df["house age"] = 2026 - df["Built Year"]

# %%
# STEP 12: Adding a new coloumn to the data using the existing columns.

# %%
df["age Category"] = pd.cut( df["house age"], bins= [0,10,30,60,200], labels = ["New", "mid-aged", "old", "very-old"])  #also assigning tags to the calculated data

# %%
df["estimated cost"] = df["living area"]*150
df["profit_margin"] = (df["price"] - df["estimated cost"])/ df["price"]

# %%
df.dtypes
# Out:
# id                                                int64
# Date                                     datetime64[ns]
# number of bedrooms                                int64
# number of bathrooms                               int64
# living area                                       int64
# lot area                                          int64
# number of floors                                float64
# waterfront present                                 bool
# number of views                                   int64
# condition of the house                            int64
# grade of the house                                int64
# Area of the house(excluding basement)             int64
# Area of the basement                              int64
# Built Year                                        int64
# Renovation Year                                   int64
# Postal Code                                    category
# Lattitude                                       float64
# ...

# %%
df.head()
# Out:
#            id                          Date  number of bedrooms  \
# 0  6762810145 1970-01-01 00:00:00.000042491                   5
# 1  6762810635 1970-01-01 00:00:00.000042491                   4
# 2  6762810998 1970-01-01 00:00:00.000042491                   5
# 3  6762812605 1970-01-01 00:00:00.000042491                   4
# 4  6762812919 1970-01-01 00:00:00.000042491                   3
#
#    number of bathrooms  living area  lot area  number of floors  \
# 0                    2         3650      9050               2.0
# 1                    2         2920      4000               1.5
# 2                    2         2910      9480               1.5
# 3                    2         3310     42998               2.0
# 4                    2         2710      4500               1.5
#
#    waterfront present  number of views  condition of the house  ...  \
# 0               False                4                       5  ...
# ...

# %%
df.to_csv('cleaned_house_data.csv', index=False)  #saving the cleaned and modified csv
